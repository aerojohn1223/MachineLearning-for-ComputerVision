# %%
import tensorflow as tf

# %%
def residual(x, filters):
  filter1, filter2, filter3 = filters

  #layer1
  y = tf.keras.layers.Conv2D(filters=filter1, kernel_size=1)(x)
  y = tf.keras.layers.BatchNormalization(axis=3)(y)
  y = tf.keras.layers.Activation('relu')(y)

  #layer2
  y = tf.keras.layers.Conv2D(filters=filter2, kernel_size=3, padding='same')(y)
  y = tf.keras.layers.BatchNormalization(axis=3)(y)
  y = tf.keras.layers.Activation('relu')(y)

  #layer3
  y = tf.keras.layers.Conv2D(filters=filter3, kernel_size=1)(y)
  y = tf.keras.layers.BatchNormalization(axis=3)(y)
  y = tf.keras.layers.Add()([x, y])

  y = tf.keras.layers.Activation('relu')(y)

  return y

# %%
def residual_block(filters):
  return lambda x: residual(x, filters)

# %%
def conv(x, filters, strides=(2,2)):
  filter1, filter2, filter3 = filters

  y = tf.keras.layers.Conv2D(filters=filter1, kernel_size = 1, strides=strides)(x)
  y = tf.keras.layers.BatchNormalization(axis=3)(y)
  y = tf.keras.layers.Activation('relu')(y)

  y = tf.keras.layers.Conv2D(filters=filter1, kernel_size = 3, padding='same')(y)
  y = tf.keras.layers.BatchNormalization(axis=3)(y)
  y = tf.keras.layers.Activation('relu')(y)

  y = tf.keras.layers.Conv2D(filters=filter3, kernel_size=1)(y)
  y = tf.keras.layers.BatchNormalization(axis=3)(y)

  shortcut = tf.keras.layers.Conv2D(filters=filter3, kernel_size=1, strides=strides)(x)
  shortcut = tf.keras.layers.BatchNormalization(axis=3)(shortcut)

  y = tf.keras.layers.add([y, shortcut])
  y = tf.keras.layers.Activation('relu')(y)

  return y

# %%
def conv_block(filters, strides=(2, 2)):
  return lambda x: conv(x, filters, strides)

# %%
#ResNet 50

CLASSES = [i for i in range(1000)]

x = tf.keras.layers.Input(shape=[224, 224, 3])

y = tf.keras.layers.ZeroPadding2D(padding=3)(x)
y = tf.keras.layers.Conv2D(filters=64, kernel_size=7, padding='valid')(y)
y = tf.keras.layers.BatchNormalization(axis=3)(y)
y = tf.keras.layers.Activation('relu')(y)
y = tf.keras.layers.ZeroPadding2D(padding=1)(y)
y = tf.keras.layers.MaxPooling2D(pool_size=3, strides=(2, 2))(y)

y = conv_block([64, 64, 256], strides=(1,1))(y)
y = residual_block([64, 64, 256])(y)
y = residual_block([64, 64, 256])(y)

y = conv_block([128, 128, 512], strides=(2,2))(y)
y = residual_block([128, 128, 512])(y)
y = residual_block([128, 128, 512])(y)
y = residual_block([128, 128, 512])(y)

y = conv_block([256, 256, 1024], strides=(2,2))(y)
y = residual_block([256, 256, 1024])(y)
y = residual_block([256, 256, 1024])(y)
y = residual_block([256, 256, 1024])(y)

y = conv_block([512, 512, 2048], strides=(2,2))(y)
y = residual_block([512, 512, 2048])(y)
y = residual_block([512, 512, 2048])(y)

y = tf.keras.layers.GlobalAveragePooling2D()(y)
y = tf.keras.layers.Dense(len(CLASSES), activation='softmax')(y)

model = tf.keras.Model(x, y)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_11 (InputLayer)       [(None, 224, 224, 3)]        0         []
#
#  zero_padding2d_18 (ZeroPad  (None, 230, 230, 3)          0         ['input_11[0][0]']
#  ding2D)
#
#  conv2d_22 (Conv2D)          (None, 224, 224, 64)         9472      ['zero_padding2d_18[0][0]']
#
#  batch_normalization_21 (Ba  (None, 224, 224, 64)         256       ['conv2d_22[0][0]']
#  tchNormalization)
#
#  activation_16 (Activation)  (None, 224, 224, 64)         0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  zero_padding2d_19 (ZeroPad  (None, 226, 226, 64)         0         ['activation_16[0][0]']
#  ding2D)
#
#  max_pooling2d_8 (MaxPoolin  (None, 112, 112, 64)         0         ['zero_padding2d_19[0][0]']
#  g2D)
#
#  conv2d_23 (Conv2D)          (None, 112, 112, 64)         4160      ['max_pooling2d_8[0][0]']
#
#  batch_normalization_22 (Ba  (None, 112, 112, 64)         256       ['conv2d_23[0][0]']
#  tchNormalization)
#
#  activation_17 (Activation)  (None, 112, 112, 64)         0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  conv2d_24 (Conv2D)          (None, 112, 112, 64)         36928     ['activation_17[0][0]']
#
#  batch_normalization_23 (Ba  (None, 112, 112, 64)         256       ['conv2d_24[0][0]']
#  tchNormalization)
#
#  activation_18 (Activation)  (None, 112, 112, 64)         0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  conv2d_25 (Conv2D)          (None, 112, 112, 256)        16640     ['activation_18[0][0]']
#
#  conv2d_26 (Conv2D)          (None, 112, 112, 256)        16640     ['max_pooling2d_8[0][0]']
#
#  batch_normalization_24 (Ba  (None, 112, 112, 256)        1024      ['conv2d_25[0][0]']
#  tchNormalization)
#
#  batch_normalization_25 (Ba  (None, 112, 112, 256)        1024      ['conv2d_26[0][0]']
#  tchNormalization)
#
#  add_2 (Add)                 (None, 112, 112, 256)        0         ['batch_normalization_24[0][0]
#                                                                     ',
#                                                                      'batch_normalization_25[0][0]
#                                                                     ']
#
#  activation_19 (Activation)  (None, 112, 112, 256)        0         ['add_2[0][0]']
#
#  conv2d_27 (Conv2D)          (None, 112, 112, 64)         16448     ['activation_19[0][0]']
#
#  batch_normalization_26 (Ba  (None, 112, 112, 64)         256       ['conv2d_27[0][0]']
#  tchNormalization)
#
#  activation_20 (Activation)  (None, 112, 112, 64)         0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  conv2d_28 (Conv2D)          (None, 112, 112, 64)         36928     ['activation_20[0][0]']
#
#  batch_normalization_27 (Ba  (None, 112, 112, 64)         256       ['conv2d_28[0][0]']
#  tchNormalization)
#
#  activation_21 (Activation)  (None, 112, 112, 64)         0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  conv2d_29 (Conv2D)          (None, 112, 112, 256)        16640     ['activation_21[0][0]']
#
#  batch_normalization_28 (Ba  (None, 112, 112, 256)        1024      ['conv2d_29[0][0]']
#  tchNormalization)
#
#  add_3 (Add)                 (None, 112, 112, 256)        0         ['activation_19[0][0]',
#                                                                      'batch_normalization_28[0][0]
#                                                                     ']
#
#  activation_22 (Activation)  (None, 112, 112, 256)        0         ['add_3[0][0]']
#
#  conv2d_30 (Conv2D)          (None, 112, 112, 64)         16448     ['activation_22[0][0]']
#
#  batch_normalization_29 (Ba  (None, 112, 112, 64)         256       ['conv2d_30[0][0]']
#  tchNormalization)
#
#  activation_23 (Activation)  (None, 112, 112, 64)         0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  conv2d_31 (Conv2D)          (None, 112, 112, 64)         36928     ['activation_23[0][0]']
#
#  batch_normalization_30 (Ba  (None, 112, 112, 64)         256       ['conv2d_31[0][0]']
#  tchNormalization)
#
#  activation_24 (Activation)  (None, 112, 112, 64)         0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  conv2d_32 (Conv2D)          (None, 112, 112, 256)        16640     ['activation_24[0][0]']
#
#  batch_normalization_31 (Ba  (None, 112, 112, 256)        1024      ['conv2d_32[0][0]']
#  tchNormalization)
#
#  add_4 (Add)                 (None, 112, 112, 256)        0         ['activation_22[0][0]',
#                                                                      'batch_normalization_31[0][0]
#                                                                     ']
#
#  activation_25 (Activation)  (None, 112, 112, 256)        0         ['add_4[0][0]']
#
#  conv2d_33 (Conv2D)          (None, 56, 56, 128)          32896     ['activation_25[0][0]']
#
#  batch_normalization_32 (Ba  (None, 56, 56, 128)          512       ['conv2d_33[0][0]']
#  tchNormalization)
#
#  activation_26 (Activation)  (None, 56, 56, 128)          0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  conv2d_34 (Conv2D)          (None, 56, 56, 128)          147584    ['activation_26[0][0]']
#
#  batch_normalization_33 (Ba  (None, 56, 56, 128)          512       ['conv2d_34[0][0]']
#  tchNormalization)
#
#  activation_27 (Activation)  (None, 56, 56, 128)          0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  conv2d_35 (Conv2D)          (None, 56, 56, 512)          66048     ['activation_27[0][0]']
#
#  conv2d_36 (Conv2D)          (None, 56, 56, 512)          131584    ['activation_25[0][0]']
#
#  batch_normalization_34 (Ba  (None, 56, 56, 512)          2048      ['conv2d_35[0][0]']
#  tchNormalization)
#
#  batch_normalization_35 (Ba  (None, 56, 56, 512)          2048      ['conv2d_36[0][0]']
#  tchNormalization)
#
#  add_5 (Add)                 (None, 56, 56, 512)          0         ['batch_normalization_34[0][0]
#                                                                     ',
#                                                                      'batch_normalization_35[0][0]
#                                                                     ']
#
#  activation_28 (Activation)  (None, 56, 56, 512)          0         ['add_5[0][0]']
#
#  conv2d_37 (Conv2D)          (None, 56, 56, 128)          65664     ['activation_28[0][0]']
#
#  batch_normalization_36 (Ba  (None, 56, 56, 128)          512       ['conv2d_37[0][0]']
#  tchNormalization)
#
#  activation_29 (Activation)  (None, 56, 56, 128)          0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  conv2d_38 (Conv2D)          (None, 56, 56, 128)          147584    ['activation_29[0][0]']
#
#  batch_normalization_37 (Ba  (None, 56, 56, 128)          512       ['conv2d_38[0][0]']
#  tchNormalization)
#
#  activation_30 (Activation)  (None, 56, 56, 128)          0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  conv2d_39 (Conv2D)          (None, 56, 56, 512)          66048     ['activation_30[0][0]']
#
#  batch_normalization_38 (Ba  (None, 56, 56, 512)          2048      ['conv2d_39[0][0]']
#  tchNormalization)
#
#  add_6 (Add)                 (None, 56, 56, 512)          0         ['activation_28[0][0]',
#                                                                      'batch_normalization_38[0][0]
#                                                                     ']
#
#  activation_31 (Activation)  (None, 56, 56, 512)          0         ['add_6[0][0]']
#
#  conv2d_40 (Conv2D)          (None, 56, 56, 128)          65664     ['activation_31[0][0]']
#
#  batch_normalization_39 (Ba  (None, 56, 56, 128)          512       ['conv2d_40[0][0]']
#  tchNormalization)
#
#  activation_32 (Activation)  (None, 56, 56, 128)          0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  conv2d_41 (Conv2D)          (None, 56, 56, 128)          147584    ['activation_32[0][0]']
#
#  batch_normalization_40 (Ba  (None, 56, 56, 128)          512       ['conv2d_41[0][0]']
#  tchNormalization)
#
#  activation_33 (Activation)  (None, 56, 56, 128)          0         ['batch_normalization_40[0][0]
#                                                                     ']
#
#  conv2d_42 (Conv2D)          (None, 56, 56, 512)          66048     ['activation_33[0][0]']
#
#  batch_normalization_41 (Ba  (None, 56, 56, 512)          2048      ['conv2d_42[0][0]']
#  tchNormalization)
#
#  add_7 (Add)                 (None, 56, 56, 512)          0         ['activation_31[0][0]',
#                                                                      'batch_normalization_41[0][0]
#                                                                     ']
#
#  activation_34 (Activation)  (None, 56, 56, 512)          0         ['add_7[0][0]']
#
#  conv2d_43 (Conv2D)          (None, 56, 56, 128)          65664     ['activation_34[0][0]']
#
#  batch_normalization_42 (Ba  (None, 56, 56, 128)          512       ['conv2d_43[0][0]']
#  tchNormalization)
#
#  activation_35 (Activation)  (None, 56, 56, 128)          0         ['batch_normalization_42[0][0]
#                                                                     ']
#
#  conv2d_44 (Conv2D)          (None, 56, 56, 128)          147584    ['activation_35[0][0]']
#
#  batch_normalization_43 (Ba  (None, 56, 56, 128)          512       ['conv2d_44[0][0]']
#  tchNormalization)
#
#  activation_36 (Activation)  (None, 56, 56, 128)          0         ['batch_normalization_43[0][0]
#                                                                     ']
#
#  conv2d_45 (Conv2D)          (None, 56, 56, 512)          66048     ['activation_36[0][0]']
#
#  batch_normalization_44 (Ba  (None, 56, 56, 512)          2048      ['conv2d_45[0][0]']
#  tchNormalization)
#
#  add_8 (Add)                 (None, 56, 56, 512)          0         ['activation_34[0][0]',
#                                                                      'batch_normalization_44[0][0]
#                                                                     ']
#
#  activation_37 (Activation)  (None, 56, 56, 512)          0         ['add_8[0][0]']
#
#  conv2d_46 (Conv2D)          (None, 28, 28, 256)          131328    ['activation_37[0][0]']
#
#  batch_normalization_45 (Ba  (None, 28, 28, 256)          1024      ['conv2d_46[0][0]']
#  tchNormalization)
#
#  activation_38 (Activation)  (None, 28, 28, 256)          0         ['batch_normalization_45[0][0]
#                                                                     ']
#
#  conv2d_47 (Conv2D)          (None, 28, 28, 256)          590080    ['activation_38[0][0]']
#
#  batch_normalization_46 (Ba  (None, 28, 28, 256)          1024      ['conv2d_47[0][0]']
#  tchNormalization)
#
#  activation_39 (Activation)  (None, 28, 28, 256)          0         ['batch_normalization_46[0][0]
#                                                                     ']
#
#  conv2d_48 (Conv2D)          (None, 28, 28, 1024)         263168    ['activation_39[0][0]']
#
#  conv2d_49 (Conv2D)          (None, 28, 28, 1024)         525312    ['activation_37[0][0]']
#
#  batch_normalization_47 (Ba  (None, 28, 28, 1024)         4096      ['conv2d_48[0][0]']
#  tchNormalization)
#
#  batch_normalization_48 (Ba  (None, 28, 28, 1024)         4096      ['conv2d_49[0][0]']
#  tchNormalization)
#
#  add_9 (Add)                 (None, 28, 28, 1024)         0         ['batch_normalization_47[0][0]
#                                                                     ',
#                                                                      'batch_normalization_48[0][0]
#                                                                     ']
#
#  activation_40 (Activation)  (None, 28, 28, 1024)         0         ['add_9[0][0]']
#
#  conv2d_50 (Conv2D)          (None, 28, 28, 256)          262400    ['activation_40[0][0]']
#
#  batch_normalization_49 (Ba  (None, 28, 28, 256)          1024      ['conv2d_50[0][0]']
#  tchNormalization)
#
#  activation_41 (Activation)  (None, 28, 28, 256)          0         ['batch_normalization_49[0][0]
#                                                                     ']
#
#  conv2d_51 (Conv2D)          (None, 28, 28, 256)          590080    ['activation_41[0][0]']
#
#  batch_normalization_50 (Ba  (None, 28, 28, 256)          1024      ['conv2d_51[0][0]']
#  tchNormalization)
#
#  activation_42 (Activation)  (None, 28, 28, 256)          0         ['batch_normalization_50[0][0]
#                                                                     ']
#
#  conv2d_52 (Conv2D)          (None, 28, 28, 1024)         263168    ['activation_42[0][0]']
#
#  batch_normalization_51 (Ba  (None, 28, 28, 1024)         4096      ['conv2d_52[0][0]']
#  tchNormalization)
#
#  add_10 (Add)                (None, 28, 28, 1024)         0         ['activation_40[0][0]',
#                                                                      'batch_normalization_51[0][0]
#                                                                     ']
#
#  activation_43 (Activation)  (None, 28, 28, 1024)         0         ['add_10[0][0]']
#
#  conv2d_53 (Conv2D)          (None, 28, 28, 256)          262400    ['activation_43[0][0]']
#
#  batch_normalization_52 (Ba  (None, 28, 28, 256)          1024      ['conv2d_53[0][0]']
#  tchNormalization)
#
#  activation_44 (Activation)  (None, 28, 28, 256)          0         ['batch_normalization_52[0][0]
#                                                                     ']
#
#  conv2d_54 (Conv2D)          (None, 28, 28, 256)          590080    ['activation_44[0][0]']
#
#  batch_normalization_53 (Ba  (None, 28, 28, 256)          1024      ['conv2d_54[0][0]']
#  tchNormalization)
#
#  activation_45 (Activation)  (None, 28, 28, 256)          0         ['batch_normalization_53[0][0]
#                                                                     ']
#
#  conv2d_55 (Conv2D)          (None, 28, 28, 1024)         263168    ['activation_45[0][0]']
#
#  batch_normalization_54 (Ba  (None, 28, 28, 1024)         4096      ['conv2d_55[0][0]']
#  tchNormalization)
#
#  add_11 (Add)                (None, 28, 28, 1024)         0         ['activation_43[0][0]',
#                                                                      'batch_normalization_54[0][0]
#                                                                     ']
#
#  activation_46 (Activation)  (None, 28, 28, 1024)         0         ['add_11[0][0]']
#
#  conv2d_56 (Conv2D)          (None, 28, 28, 256)          262400    ['activation_46[0][0]']
#
#  batch_normalization_55 (Ba  (None, 28, 28, 256)          1024      ['conv2d_56[0][0]']
#  tchNormalization)
#
#  activation_47 (Activation)  (None, 28, 28, 256)          0         ['batch_normalization_55[0][0]
#                                                                     ']
#
#  conv2d_57 (Conv2D)          (None, 28, 28, 256)          590080    ['activation_47[0][0]']
#
#  batch_normalization_56 (Ba  (None, 28, 28, 256)          1024      ['conv2d_57[0][0]']
#  tchNormalization)
#
#  activation_48 (Activation)  (None, 28, 28, 256)          0         ['batch_normalization_56[0][0]
#                                                                     ']
#
#  conv2d_58 (Conv2D)          (None, 28, 28, 1024)         263168    ['activation_48[0][0]']
#
#  batch_normalization_57 (Ba  (None, 28, 28, 1024)         4096      ['conv2d_58[0][0]']
#  tchNormalization)
#
#  add_12 (Add)                (None, 28, 28, 1024)         0         ['activation_46[0][0]',
#                                                                      'batch_normalization_57[0][0]
#                                                                     ']
#
#  activation_49 (Activation)  (None, 28, 28, 1024)         0         ['add_12[0][0]']
#
#  conv2d_59 (Conv2D)          (None, 14, 14, 512)          524800    ['activation_49[0][0]']
#
#  batch_normalization_58 (Ba  (None, 14, 14, 512)          2048      ['conv2d_59[0][0]']
#  tchNormalization)
#
#  activation_50 (Activation)  (None, 14, 14, 512)          0         ['batch_normalization_58[0][0]
#                                                                     ']
#
#  conv2d_60 (Conv2D)          (None, 14, 14, 512)          2359808   ['activation_50[0][0]']
#
#  batch_normalization_59 (Ba  (None, 14, 14, 512)          2048      ['conv2d_60[0][0]']
#  tchNormalization)
#
#  activation_51 (Activation)  (None, 14, 14, 512)          0         ['batch_normalization_59[0][0]
#                                                                     ']
#
#  conv2d_61 (Conv2D)          (None, 14, 14, 2048)         1050624   ['activation_51[0][0]']
#
#  conv2d_62 (Conv2D)          (None, 14, 14, 2048)         2099200   ['activation_49[0][0]']
#
#  batch_normalization_60 (Ba  (None, 14, 14, 2048)         8192      ['conv2d_61[0][0]']
#  tchNormalization)
#
#  batch_normalization_61 (Ba  (None, 14, 14, 2048)         8192      ['conv2d_62[0][0]']
#  tchNormalization)
#
#  add_13 (Add)                (None, 14, 14, 2048)         0         ['batch_normalization_60[0][0]
#                                                                     ',
#                                                                      'batch_normalization_61[0][0]
#                                                                     ']
#
#  activation_52 (Activation)  (None, 14, 14, 2048)         0         ['add_13[0][0]']
#
#  conv2d_63 (Conv2D)          (None, 14, 14, 512)          1049088   ['activation_52[0][0]']
#
#  batch_normalization_62 (Ba  (None, 14, 14, 512)          2048      ['conv2d_63[0][0]']
#  tchNormalization)
#
#  activation_53 (Activation)  (None, 14, 14, 512)          0         ['batch_normalization_62[0][0]
#                                                                     ']
#
#  conv2d_64 (Conv2D)          (None, 14, 14, 512)          2359808   ['activation_53[0][0]']
#
#  batch_normalization_63 (Ba  (None, 14, 14, 512)          2048      ['conv2d_64[0][0]']
#  tchNormalization)
#
#  activation_54 (Activation)  (None, 14, 14, 512)          0         ['batch_normalization_63[0][0]
#                                                                     ']
#
#  conv2d_65 (Conv2D)          (None, 14, 14, 2048)         1050624   ['activation_54[0][0]']
#
#  batch_normalization_64 (Ba  (None, 14, 14, 2048)         8192      ['conv2d_65[0][0]']
#  tchNormalization)
#
#  add_14 (Add)                (None, 14, 14, 2048)         0         ['activation_52[0][0]',
#                                                                      'batch_normalization_64[0][0]
#                                                                     ']
#
#  activation_55 (Activation)  (None, 14, 14, 2048)         0         ['add_14[0][0]']
#
#  conv2d_66 (Conv2D)          (None, 14, 14, 512)          1049088   ['activation_55[0][0]']
#
#  batch_normalization_65 (Ba  (None, 14, 14, 512)          2048      ['conv2d_66[0][0]']
#  tchNormalization)
#
#  activation_56 (Activation)  (None, 14, 14, 512)          0         ['batch_normalization_65[0][0]
#                                                                     ']
#
#  conv2d_67 (Conv2D)          (None, 14, 14, 512)          2359808   ['activation_56[0][0]']
#
#  batch_normalization_66 (Ba  (None, 14, 14, 512)          2048      ['conv2d_67[0][0]']
#  tchNormalization)
#
#  activation_57 (Activation)  (None, 14, 14, 512)          0         ['batch_normalization_66[0][0]
#                                                                     ']
#
#  conv2d_68 (Conv2D)          (None, 14, 14, 2048)         1050624   ['activation_57[0][0]']
#
#  batch_normalization_67 (Ba  (None, 14, 14, 2048)         8192      ['conv2d_68[0][0]']
#  tchNormalization)
#
#  add_15 (Add)                (None, 14, 14, 2048)         0         ['activation_55[0][0]',
#                                                                      'batch_normalization_67[0][0]
#                                                                     ']
#
#  activation_58 (Activation)  (None, 14, 14, 2048)         0         ['add_15[0][0]']
#
#  global_average_pooling2d (  (None, 2048)                 0         ['activation_58[0][0]']
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 1000)                 2049000   ['global_average_pooling2d[0][
#                                                                     0]']
#
# ==================================================================================================
# Total params: 23393128 (89.24 MB)
# Trainable params: 23346152 (89.06 MB)
# Non-trainable params: 46976 (183.50 KB)
# __________________________________________________________________________________________________
