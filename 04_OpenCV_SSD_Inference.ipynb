# %% [markdown]
# #OpenCV DNN을 이용하여 SSD 기반 Object Detection 수행
#
#
# 1) Tensorflow에서 Pretrained된 모델 파일을 OpenCV에서 로드하여 이미지와 영상에 대한 Object Detection 수행
#
#
# 2) SSD+Inception과 SSD+MobileNEt v3를 모두 테스트
#
#
# 3) CPU기반 환경에서 SSD의 Inference 속도 주시

# %%
# !mkdir /content/beatle
# !wget -o /content/beatle/beatles01.jpg https://raw.githubusercontent.com/chulminkw/DLCV/master/data/image/beatles01.jpg

# %%
# !mkdir ./pretrained

# !wget -O ./pretrained/ssd_inception_v2_coco_2017_11_17.tar.gz http://download.tensorflow.org/models/object_detection/ssd_inception_v2_coco_2017_11_17.tar.gz
# !wget -O ./pretrained/ssd_config_01.pbtxt  https://raw.githubusercontent.com/opencv/opencv_extra/master/testdata/dnn/ssd_inception_v2_coco_2017_11_17.pbtxt

# !tar -xvf ./pretrained/ssd_inception*.tar.gz -C ./pretrained
# Out:
# --2023-10-03 06:48:05--  http://download.tensorflow.org/models/object_detection/ssd_inception_v2_coco_2017_11_17.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 142.250.101.207, 142.251.2.207, 74.125.137.207, ...
# Connecting to download.tensorflow.org (download.tensorflow.org)|142.250.101.207|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 278126337 (265M) [application/x-tar]
# Saving to: ‘./pretrained/ssd_inception_v2_coco_2017_11_17.tar.gz’
#
# ./pretrained/ssd_in 100%[===================>] 265.24M  80.7MB/s    in 3.3s
#
# 2023-10-03 06:48:09 (80.7 MB/s) - ‘./pretrained/ssd_inception_v2_coco_2017_11_17.tar.gz’ saved [278126337/278126337]
#
# --2023-10-03 06:48:09--  https://raw.githubusercontent.com/opencv/opencv_extra/master/testdata/dnn/ssd_inception_v2_coco_2017_11_17.pbtxt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 117525 (115K) [text/plain]
# Saving to: ‘./pretrained/ssd_config_01.pbtxt’
#
# ./pretrained/ssd_co 100%[===================>] 114.77K  --.-KB/s    in 0.02s
#
# 2023-10-03 06:48:09 (5.92 MB/s) - ‘./pretrained/ssd_config_01.pbtxt’ saved [117525/117525]
#
# ssd_inception_v2_coco_2017_11_17/
# ssd_inception_v2_coco_2017_11_17/model.ckpt.index
# ssd_inception_v2_coco_2017_11_17/model.ckpt.meta
# ssd_inception_v2_coco_2017_11_17/frozen_inference_graph.pb
# ssd_inception_v2_coco_2017_11_17/model.ckpt.data-00000-of-00001
# ssd_inception_v2_coco_2017_11_17/saved_model/
# ssd_inception_v2_coco_2017_11_17/saved_model/saved_model.pb
# ssd_inception_v2_coco_2017_11_17/saved_model/variables/
# ssd_inception_v2_coco_2017_11_17/checkpoint

# %%
# !pwd
# !ls -lia ./pretrained/ssd_inception*
# Out:
# /content
# 1048686 -rw-r--r-- 1 root   root 278126337 Nov 18  2017 ./pretrained/ssd_inception_v2_coco_2017_11_17.tar.gz
#
# ./pretrained/ssd_inception_v2_coco_2017_11_17:
# total 201120
# 1048688 drwxr-x--- 3 275875 5000      4096 Nov 18  2017 .
# 1048685 drwxr-xr-x 3 root   root      4096 Oct  3 06:48 ..
# 1048696 -rw-r----- 1 275875 5000        77 Nov 18  2017 checkpoint
# 1048691 -rw-r----- 1 275875 5000 101987441 Nov 18  2017 frozen_inference_graph.pb
# 1048692 -rw-r----- 1 275875 5000 100214372 Nov 18  2017 model.ckpt.data-00000-of-00001
# 1048689 -rw-r----- 1 275875 5000     18073 Nov 18  2017 model.ckpt.index
# 1048690 -rw-r----- 1 275875 5000   3701354 Nov 18  2017 model.ckpt.meta
# 1048693 drwxr-x--- 3 275875 5000      4096 Nov 18  2017 saved_model

# %% [markdown]
# #dnn에서 readNetFromTensorflow()로 tensorflow inference 모델을 로딩

# %%
import cv2

cv_net = cv2.dnn.readNetFromTensorflow('/content/pretrained/ssd_inception_v2_coco_2017_11_17/frozen_inference_graph.pb',
                                       '/content/pretrained/ssd_config_01.pbtxt')

# %%
labels_to_names = {1:'person',2:'bicycle',3:'car',4:'motorcycle',5:'airplane',6:'bus',7:'train',8:'truck',9:'boat',10:'traffic light',
                    11:'fire hydrant',12:'street sign',13:'stop sign',14:'parking meter',15:'bench',16:'bird',17:'cat',18:'dog',19:'horse',20:'sheep',
                    21:'cow',22:'elephant',23:'bear',24:'zebra',25:'giraffe',26:'hat',27:'backpack',28:'umbrella',29:'shoe',30:'eye glasses',
                    31:'handbag',32:'tie',33:'suitcase',34:'frisbee',35:'skis',36:'snowboard',37:'sports ball',38:'kite',39:'baseball bat',40:'baseball glove',
                    41:'skateboard',42:'surfboard',43:'tennis racket',44:'bottle',45:'plate',46:'wine glass',47:'cup',48:'fork',49:'knife',50:'spoon',
                    51:'bowl',52:'banana',53:'apple',54:'sandwich',55:'orange',56:'broccoli',57:'carrot',58:'hot dog',59:'pizza',60:'donut',
                    61:'cake',62:'chair',63:'couch',64:'potted plant',65:'bed',66:'mirror',67:'dining table',68:'window',69:'desk',70:'toilet',
                    71:'door',72:'tv',73:'laptop',74:'mouse',75:'remote',76:'keyboard',77:'cell phone',78:'microwave',79:'oven',80:'toaster',
                    81:'sink',82:'refrigerator',83:'blender',84:'book',85:'clock',86:'vase',87:'scissors',88:'teddy bear',89:'hair drier',90:'toothbrush',
                    91:'hair brush'}

# %% [markdown]
# #이미지를 Preprocess해서 Network에 입력. Object Detection을 하고 결과를 시각화

# %%
import matplotlib.pyplot as plt

img = cv2.imread('/content/beatles01.jpg')

# %%
rows = img.shape[0]
cols = img.shape[1]

draw_img = img.copy()

#SSD의 input size는 300, 300임.
cv_net.setInput(cv2.dnn.blobFromImage(img, size=(300, 300), swapRB=True, crop=False))

cv_out = cv_net.forward()
print(cv_out.shape)

#bounding box 테두리와 글씨 색 지정
green_color = (0, 255, 0)
red_color= (0, 0, 255)

#검출된 객체들을 iteration을 통해 추출
for detection in cv_out[0, 0, :, :]:
  score = float(detection[2])
  class_id = int(detection[1])

  if score > 0.4:
    left = detection[3]*cols
    top = detection[4]*rows
    right = detection[5]*cols
    bottom = detection[6]*rows

    caption = "{}: {:.4f}".format(labels_to_names[class_id], score)

    cv2.rectangle(draw_img, (int(left), int(top)), (int(right), int(bottom)), color=green_color, thickness=2)
    cv2.putText(draw_img, caption, (int(left), int(top - 5)), cv2.FONT_HERSHEY_SIMPLEX, 0.7, red_color, 2)
    print(caption, class_id)

img_rgb = cv2.cvtColor(draw_img, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(12, 12))
plt.imshow(img_rgb)
# Out:
# (1, 1, 100, 7)
# person: 0.9696 1
# person: 0.9660 1
# person: 0.8916 1
# car: 0.8609 3
# car: 0.7223 3
# car: 0.7184 3
# car: 0.7095 3
# person: 0.6298 1
# car: 0.5949 3
# car: 0.5511 3

# %%
#function for image object detection

import time

def get_detected_img(cv_net, img_array, score_threshold, is_print=True):

    rows = img_array.shape[0]
    cols = img_array.shape[1]

    draw_img = img_array.copy()

    cv_net.setInput(cv2.dnn.blobFromImage(img_array, size=(300, 300), swapRB=True, crop=False))

    start = time.time()
    cv_out = cv_net.forward()

    green_color=(0, 255, 0)
    red_color=(0, 0, 255)

    for detection in cv_out[0,0,:,:]:
        score = float(detection[2])
        class_id = int(detection[1])

        if score > score_threshold:
            left = detection[3] * cols
            top = detection[4] * rows
            right = detection[5] * cols
            bottom = detection[6] * rows
            caption = "{}: {:.4f}".format(labels_to_names[class_id], score)

            cv2.rectangle(draw_img, (int(left), int(top)), (int(right), int(bottom)), color=green_color, thickness=2)
            cv2.putText(draw_img, caption, (int(left), int(top - 5)), cv2.FONT_HERSHEY_SIMPLEX, 0.7, red_color, 2)
    if is_print:
        print('Detection 수행시간:',round(time.time() - start, 2),"초")

    return draw_img

# %% [markdown]
# #Video Object Detection 수행

# %%
# !wget -O /content/Jonh_Wick_small.mp4 https://github.com/chulminkw/DLCV/blob/master/data/video/John_Wick_small.mp4?raw=true
# Out:
# --2023-10-03 07:09:12--  https://github.com/chulminkw/DLCV/blob/master/data/video/John_Wick_small.mp4?raw=true
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/chulminkw/DLCV/raw/master/data/video/John_Wick_small.mp4 [following]
# --2023-10-03 07:09:12--  https://github.com/chulminkw/DLCV/raw/master/data/video/John_Wick_small.mp4
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/chulminkw/DLCV/master/data/video/John_Wick_small.mp4 [following]
# --2023-10-03 07:09:13--  https://raw.githubusercontent.com/chulminkw/DLCV/master/data/video/John_Wick_small.mp4
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1794863 (1.7M) [application/octet-stream]
# Saving to: ‘/content/Jonh_Wick_small.mp4’
#
# /content/Jonh_Wick_ 100%[===================>]   1.71M  --.-KB/s    in 0.04s
#
# 2023-10-03 07:09:13 (48.6 MB/s) - ‘/content/Jonh_Wick_small.mp4’ saved [1794863/1794863]

# %%
#fast RCNN과 동일
def do_detected_video(cv_net, input_path, output_path, score_threshold, is_print):

    cap = cv2.VideoCapture(input_path)

    codec = cv2.VideoWriter_fourcc(*'XVID')

    vid_size = (round(cap.get(cv2.CAP_PROP_FRAME_WIDTH)),round(cap.get(cv2.CAP_PROP_FRAME_HEIGHT)))
    vid_fps = cap.get(cv2.CAP_PROP_FPS)

    vid_writer = cv2.VideoWriter(output_path, codec, vid_fps, vid_size)

    frame_cnt = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    print('총 Frame 갯수:', frame_cnt, )

    green_color=(0, 255, 0)
    red_color=(0, 0, 255)
    while True:
        hasFrame, img_frame = cap.read()
        if not hasFrame:
            print('더 이상 처리할 frame이 없습니다.')
            break

        returned_frame = get_detected_img(cv_net, img_frame, score_threshold=score_threshold, is_print=True)
        vid_writer.write(returned_frame)
    # end of while loop

    vid_writer.release()
    cap.release()

# %%
do_detected_video(cv_net, '/content/Jonh_Wick_small.mp4', '/content/John_Wick_small_incept.mp4', 0.2, False)
# Out:
# 총 Frame 갯수: 58
# Detection 수행시간: 0.18 초
# Detection 수행시간: 0.18 초
# Detection 수행시간: 0.18 초
# Detection 수행시간: 0.17 초
# Detection 수행시간: 0.17 초
# Detection 수행시간: 0.18 초
# Detection 수행시간: 0.18 초
# Detection 수행시간: 0.19 초
# Detection 수행시간: 0.17 초
# Detection 수행시간: 0.18 초
# Detection 수행시간: 0.18 초
# Detection 수행시간: 0.19 초
# Detection 수행시간: 0.17 초
# Detection 수행시간: 0.17 초
# Detection 수행시간: 0.18 초
# Detection 수행시간: 0.18 초
# Detection 수행시간: 0.17 초
# Detection 수행시간: 0.18 초
# Detection 수행시간: 0.17 초
# Detection 수행시간: 0.18 초
# Detection 수행시간: 0.18 초
# Detection 수행시간: 0.18 초
# Detection 수행시간: 0.19 초
# Detection 수행시간: 0.17 초
# Detection 수행시간: 0.17 초
# Detection 수행시간: 0.17 초
# Detection 수행시간: 0.18 초
# Detection 수행시간: 0.18 초
# Detection 수행시간: 0.22 초
# Detection 수행시간: 0.29 초
# Detection 수행시간: 0.32 초
# Detection 수행시간: 0.3 초
# Detection 수행시간: 0.29 초
# Detection 수행시간: 0.3 초
# Detection 수행시간: 0.31 초
# Detection 수행시간: 0.31 초
# Detection 수행시간: 0.3 초
# Detection 수행시간: 0.17 초
# Detection 수행시간: 0.18 초
# Detection 수행시간: 0.18 초
# Detection 수행시간: 0.17 초
# Detection 수행시간: 0.17 초
# Detection 수행시간: 0.18 초
# Detection 수행시간: 0.16 초
# Detection 수행시간: 0.19 초
# Detection 수행시간: 0.19 초
# Detection 수행시간: 0.16 초
# Detection 수행시간: 0.19 초
# Detection 수행시간: 0.19 초
# Detection 수행시간: 0.17 초
# Detection 수행시간: 0.19 초
# Detection 수행시간: 0.17 초
# Detection 수행시간: 0.17 초
# Detection 수행시간: 0.17 초
# Detection 수행시간: 0.18 초
# Detection 수행시간: 0.19 초
# Detection 수행시간: 0.16 초
# Detection 수행시간: 0.16 초
# 더 이상 처리할 frame이 없습니다.

# %% [markdown]
# #SSD + MobileNet v3 Object Detection
# - SSD + MobileNet v3 backbone은 opencv dnn 모듈이 아니라 dnn_DetectionModel() 함수로 생성이 가능함. 그리고 이를 사용하기 위해서는 Opencv의 버전을 업그레이드 해야함.

# %%
# !mkdir ./pretrained
# !wget -O ./pretrained/ssd_mobilenet_v3_large_coco_2020_01_14.tar.gz http://download.tensorflow.org/models/object_detection/ssd_mobilenet_v3_large_coco_2020_01_14.tar.gz
# !wget -O ./pretrained/ssd_config_02.pbtxt https://gist.githubusercontent.com/dkurt/54a8e8b51beb3bd3f770b79e56927bd7/raw/2a20064a9d33b893dd95d2567da126d0ecd03e85/ssd_mobilenet_v3_large_coco_2020_01_14.pbtxt

# !!tar -xvf ./pretrained/ssd_mobilenet*.tar.gz -C ./pretrained
# Out:
# mkdir: cannot create directory ‘./pretrained’: File exists
# --2023-10-03 07:21:31--  http://download.tensorflow.org/models/object_detection/ssd_mobilenet_v3_large_coco_2020_01_14.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 142.250.101.207, 142.251.2.207, 74.125.137.207, ...
# Connecting to download.tensorflow.org (download.tensorflow.org)|142.250.101.207|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 49318766 (47M) [application/gzip]
# Saving to: ‘./pretrained/ssd_mobilenet_v3_large_coco_2020_01_14.tar.gz’
#
# ./pretrained/ssd_mo 100%[===================>]  47.03M  73.3MB/s    in 0.6s
#
# 2023-10-03 07:21:32 (73.3 MB/s) - ‘./pretrained/ssd_mobilenet_v3_large_coco_2020_01_14.tar.gz’ saved [49318766/49318766]
#
# --2023-10-03 07:21:32--  https://gist.githubusercontent.com/dkurt/54a8e8b51beb3bd3f770b79e56927bd7/raw/2a20064a9d33b893dd95d2567da126d0ecd03e85/ssd_mobilenet_v3_large_coco_2020_01_14.pbtxt
# Resolving gist.githubusercontent.com (gist.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to gist.githubusercontent.com (gist.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 182178 (178K) [text/plain]
# Saving to: ‘./pretrained/ssd_config_02.pbtxt’
#
# ./pretrained/ssd_co 100%[===================>] 177.91K  --.-KB/s    in 0.02s
#
# 2023-10-03 07:21:32 (9.71 MB/s) - ‘./pretrained/ssd_config_02.pbtxt’ saved [182178/182178]
# ['ssd_mobilenet_v3_large_coco_2020_01_14/pipeline.config',
#  'ssd_mobilenet_v3_large_coco_2020_01_14/model.ckpt.index',
#  'ssd_mobilenet_v3_large_coco_2020_01_14/model.ckpt.data-00000-of-00001',
#  'ssd_mobilenet_v3_large_coco_2020_01_14/model.tflite',
#  'ssd_mobilenet_v3_large_coco_2020_01_14/frozen_inference_graph.pb',
#  'ssd_mobilenet_v3_large_coco_2020_01_14/checkpoint',
#  'ssd_mobilenet_v3_large_coco_2020_01_14/model.ckpt.meta',
#  'ssd_mobilenet_v3_large_coco_2020_01_14/']

# %%
# !pip install opencv-python==4.8.1.78
# Out:
# Collecting opencv-python==4.8.1.78
#   Downloading opencv_python-4.8.1.78-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (61.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 MB 9.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python==4.8.1.78) (1.23.5)
# Installing collected packages: opencv-python
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.8.0.76
#     Uninstalling opencv-python-4.8.0.76:
#       Successfully uninstalled opencv-python-4.8.0.76
# Successfully installed opencv-python-4.8.1.78

# %%
import cv2

cv_net_m = cv2.dnn_DetectionModel('/content/pretrained/ssd_mobilenet_v3_large_coco_2020_01_14/frozen_inference_graph.pb',
                                  '/content/pretrained/ssd_config_02.pbtxt')

cv_net_m.setInputSize(320, 320)
cv_net_m.setInputScale(1.0 / 127.5)
cv_net_m.setInputMean((127.5, 127.5, 127.5))
cv_net_m.setInputSwapRB(True)
# Out:
# < cv2.dnn.Model 0x7ee554a33f10>

# %% [markdown]
# #dnn model 객체의 detect() 메소드는 입력 이미지를 받아서 특정 confidence threshold 이상의 모든 object inference 결과를 반환함.
#
# - class id값, confidence score값, bbox 좌표값이 array로 반환됨.
# - bbox 좌표값의 경우 0~1 사이 값이 아니라 정수형의 위치값이 반환됨. 단, xmin, ymin, width, height 형태로 반환되므로 유의해야함.

# %%
img = cv2.imread('/content/beatles01.jpg')
draw_img = img.copy()

classes, confidences, boxes = cv_net_m.detect(img, confThreshold=0.5)

# %%
classes, confidences, boxes
# Out:
# (array([1, 1, 1, 1, 3, 3, 3, 3, 3, 3, 1], dtype=int32),
#  array([0.77957064, 0.7573837 , 0.7533258 , 0.7124602 , 0.6756757 ,
#         0.6396257 , 0.5794208 , 0.57735324, 0.5534913 , 0.5314795 ,
#         0.5063211 ], dtype=float32),
#  array([[ 48, 258, 154, 291],
#         [213, 252, 158, 298],
#         [386, 266, 167, 300],
#         [560, 251, 153, 322],
#         [496, 226,  80,  67],
#         [451, 227,  28,  21],
#         [472, 226,  43,  35],
#         [375, 219,  17,  17],
#         [415, 220,  18,  17],
#         [314, 227,  38,  23],
#         [258, 259, 101, 268]], dtype=int32))

# %%
labels_to_names = {1:'person',2:'bicycle',3:'car',4:'motorcycle',5:'airplane',6:'bus',7:'train',8:'truck',9:'boat',10:'traffic light',
                    11:'fire hydrant',12:'street sign',13:'stop sign',14:'parking meter',15:'bench',16:'bird',17:'cat',18:'dog',19:'horse',20:'sheep',
                    21:'cow',22:'elephant',23:'bear',24:'zebra',25:'giraffe',26:'hat',27:'backpack',28:'umbrella',29:'shoe',30:'eye glasses',
                    31:'handbag',32:'tie',33:'suitcase',34:'frisbee',35:'skis',36:'snowboard',37:'sports ball',38:'kite',39:'baseball bat',40:'baseball glove',
                    41:'skateboard',42:'surfboard',43:'tennis racket',44:'bottle',45:'plate',46:'wine glass',47:'cup',48:'fork',49:'knife',50:'spoon',
                    51:'bowl',52:'banana',53:'apple',54:'sandwich',55:'orange',56:'broccoli',57:'carrot',58:'hot dog',59:'pizza',60:'donut',
                    61:'cake',62:'chair',63:'couch',64:'potted plant',65:'bed',66:'mirror',67:'dining table',68:'window',69:'desk',70:'toilet',
                    71:'door',72:'tv',73:'laptop',74:'mouse',75:'remote',76:'keyboard',77:'cell phone',78:'microwave',79:'oven',80:'toaster',
                    81:'sink',82:'refrigerator',83:'blender',84:'book',85:'clock',86:'vase',87:'scissors',88:'teddy bear',89:'hair drier',90:'toothbrush',
                    91:'hair brush'}

# %%
import matplotlib.pyplot as plt

green_color = (0, 255, 0)
red_color = (0, 0, 255)

for class_id, confidence_score, box in zip(classes.flatten(), confidences.flatten(), boxes): #2차원을 1차원으로 뭉갠다.
  if confidence_score > 0.5: #원래 없어도 되는데 필터링을 더 하고 싶을 때 사용.
    caption = "{}: {:.4f}".format(labels_to_names[class_id], confidence_score)
    cv2.rectangle(draw_img, (box[0], box[1]), (box[0]+box[2], box[1]+box[3]), color=green_color, thickness=2)
    cv2.putText(draw_img, caption, (box[0], box[1]), cv2.FONT_HERSHEY_SIMPLEX, 0.6, red_color, 2)
    print(caption, class_id, box)

draw_img = cv2.cvtColor(draw_img, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(12, 12))
plt.imshow(draw_img)
# Out:
# person: 0.7796 1 [ 48 258 154 291]
# person: 0.7574 1 [213 252 158 298]
# person: 0.7533 1 [386 266 167 300]
# person: 0.7125 1 [560 251 153 322]
# car: 0.6757 3 [496 226  80  67]
# car: 0.6396 3 [451 227  28  21]
# car: 0.5794 3 [472 226  43  35]
# car: 0.5774 3 [375 219  17  17]
# car: 0.5535 3 [415 220  18  17]
# car: 0.5315 3 [314 227  38  23]
# person: 0.5063 1 [258 259 101 268]

# %%
import time
def get_detected_img_renew(cv_net, img_array, score_threshold, is_print=True):

  draw_img = img_array.copy()

  start = time.time()

  classes, confidences, boxes = cv_net.detect(img_array, confThreshold=0.5)

  green_color=(0, 255, 0)
  red_color=(0, 0, 255)


  for class_id, confidence_score, box in zip(classes.flatten(), confidences.flatten(), boxes):
    if confidence_score > 0.5:
      caption = "{}: {:.4f}".format(labels_to_names[class_id], confidence_score)
      cv2.rectangle(draw_img, (box[0], box[1]), (box[0]+box[2], box[1]+box[3]), color=green_color, thickness=2)
      cv2.putText(draw_img, caption, (box[0], box[1]), cv2.FONT_HERSHEY_SIMPLEX, 0.6, red_color, 2)
      print(caption)

  if is_print:
      print('Detection 수행시간:',round(time.time() - start, 2),"초")

  return draw_img

# %%
## dnn_Model을 만드는 함수 생성.
def get_cv_detection_model(pretrained_path, config_path):
  cv_net = cv2.dnn_DetectionModel(pretrained_path, config_path)
  cv_net.setInputSize(320, 320)
  cv_net.setInputScale(1.0 / 127.5)
  cv_net.setInputMean((127.5, 127.5, 127.5))
  cv_net.setInputSwapRB(True)

  return cv_net

# %%
cv_net_m = get_cv_detection_model('/content/pretrained/ssd_mobilenet_v3_large_coco_2020_01_14/frozen_inference_graph.pb',
                                  '/content/pretrained/ssd_config_02.pbtxt')

# %% [markdown]
# #Video Inference 수행

# %%
# !wget -O /content/Jonh_Wick_small.mp4 https://github.com/chulminkw/DLCV/blob/master/data/video/John_Wick_small.mp4?raw=true
# Out:
# --2023-10-03 07:58:12--  https://github.com/chulminkw/DLCV/blob/master/data/video/John_Wick_small.mp4?raw=true
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/chulminkw/DLCV/raw/master/data/video/John_Wick_small.mp4 [following]
# --2023-10-03 07:58:12--  https://github.com/chulminkw/DLCV/raw/master/data/video/John_Wick_small.mp4
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/chulminkw/DLCV/master/data/video/John_Wick_small.mp4 [following]
# --2023-10-03 07:58:12--  https://raw.githubusercontent.com/chulminkw/DLCV/master/data/video/John_Wick_small.mp4
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1794863 (1.7M) [application/octet-stream]
# Saving to: ‘/content/Jonh_Wick_small.mp4’
#
# /content/Jonh_Wick_ 100%[===================>]   1.71M  --.-KB/s    in 0.05s
#
# 2023-10-03 07:58:13 (35.3 MB/s) - ‘/content/Jonh_Wick_small.mp4’ saved [1794863/1794863]

# %%
def do_detected_video_renew(cv_net, input_path, output_path, score_threshold, is_print):

    cap = cv2.VideoCapture(input_path)

    codec = cv2.VideoWriter_fourcc(*'XVID')

    vid_size = (round(cap.get(cv2.CAP_PROP_FRAME_WIDTH)),round(cap.get(cv2.CAP_PROP_FRAME_HEIGHT)))
    vid_fps = cap.get(cv2.CAP_PROP_FPS)

    vid_writer = cv2.VideoWriter(output_path, codec, vid_fps, vid_size)

    frame_cnt = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    print('총 Frame 갯수:', frame_cnt, )

    green_color=(0, 255, 0)
    red_color=(0, 0, 255)
    while True:
        hasFrame, img_frame = cap.read()
        if not hasFrame:
            print('더 이상 처리할 frame이 없습니다.')
            break

        returned_frame = get_detected_img_renew(cv_net, img_frame, score_threshold=score_threshold, is_print=True)
        vid_writer.write(returned_frame)
    # end of while loop

    vid_writer.release()
    cap.release()

# %%
do_detected_video_renew(cv_net_m, '/content/Jonh_Wick_small.mp4', '/content/John_Wick_small_m3.mp4', 0.2, False)
# Out:
# 총 Frame 갯수: 58
# car: 0.7007
# car: 0.6426
# person: 0.6268
# car: 0.5965
# car: 0.5591
# car: 0.5143
# car: 0.5111
# person: 0.5018
# Detection 수행시간: 0.11 초
# car: 0.6978
# car: 0.6462
# person: 0.6340
# car: 0.5995
# car: 0.5576
# car: 0.5123
# car: 0.5123
# person: 0.5040
# Detection 수행시간: 0.08 초
# person: 0.7225
# car: 0.7070
# car: 0.7001
# car: 0.5805
# car: 0.5615
# Detection 수행시간: 0.07 초
# person: 0.7266
# car: 0.7232
# car: 0.6871
# car: 0.5425
# car: 0.5372
# car: 0.5029
# Detection 수행시간: 0.07 초
# car: 0.6832
# car: 0.6009
# person: 0.5702
# bus: 0.5572
# car: 0.5494
# truck: 0.5315
# Detection 수행시간: 0.08 초
# person: 0.6666
# car: 0.6634
# car: 0.5647
# car: 0.5450
# bus: 0.5379
# car: 0.5267
# car: 0.5088
# Detection 수행시간: 0.07 초
# car: 0.6620
# person: 0.6544
# car: 0.5694
# bus: 0.5468
# car: 0.5366
# car: 0.5303
# car: 0.5074
# Detection 수행시간: 0.07 초
# car: 0.7102
# bus: 0.6212
# car: 0.5881
# person: 0.5652
# car: 0.5506
# car: 0.5125
# person: 0.5110
# Detection 수행시간: 0.08 초
# car: 0.6820
# car: 0.6173
# bus: 0.5816
# person: 0.5728
# car: 0.5602
# Detection 수행시간: 0.09 초
# car: 0.6922
# car: 0.6200
# bus: 0.5714
# car: 0.5710
# person: 0.5598
# Detection 수행시간: 0.07 초
# car: 0.6907
# bus: 0.6391
# car: 0.6163
# car: 0.5757
# bus: 0.5430
# car: 0.5184
# truck: 0.5014
# Detection 수행시간: 0.08 초
# car: 0.6970
# car: 0.6618
# car: 0.6350
# bus: 0.5592
# bus: 0.5274
# person: 0.5169
# truck: 0.5166
# Detection 수행시간: 0.08 초
# car: 0.7000
# car: 0.6480
# car: 0.6263
# car: 0.5454
# car: 0.5221
# car: 0.5177
# Detection 수행시간: 0.09 초
# car: 0.7085
# car: 0.6807
# car: 0.5613
# car: 0.5403
# bus: 0.5388
# person: 0.5197
# car: 0.5136
# person: 0.5031
# Detection 수행시간: 0.08 초
# car: 0.7072
# car: 0.6766
# car: 0.5599
# car: 0.5444
# person: 0.5220
# car: 0.5126
# bus: 0.5113
# person: 0.5043
# Detection 수행시간: 0.08 초
# car: 0.6744
# car: 0.6438
# car: 0.5999
# bus: 0.5794
# car: 0.5713
# person: 0.5239
# car: 0.5191
# car: 0.5191
# person: 0.5182
# Detection 수행시간: 0.08 초
# car: 0.6590
# car: 0.6583
# car: 0.6409
# car: 0.5015
# bus: 0.5013
# Detection 수행시간: 0.09 초
# car: 0.6719
# car: 0.6581
# car: 0.6095
# car: 0.5547
# Detection 수행시간: 0.08 초
# car: 0.6711
# car: 0.6511
# car: 0.6156
# person: 0.5425
# person: 0.5196
# car: 0.5153
# car: 0.5076
# person: 0.5056
# car: 0.5011
# Detection 수행시간: 0.09 초
# car: 0.6745
# car: 0.6591
# car: 0.6156
# car: 0.5194
# person: 0.5164
# car: 0.5053
# person: 0.5027
# Detection 수행시간: 0.08 초
# car: 0.7283
# car: 0.7080
# car: 0.6928
# car: 0.5301
# person: 0.5047
# Detection 수행시간: 0.09 초
# car: 0.7233
# car: 0.6742
# car: 0.6374
# car: 0.6317
# car: 0.5307
# car: 0.5284
# person: 0.5177
# Detection 수행시간: 0.08 초
# car: 0.7660
# car: 0.6678
# car: 0.6182
# car: 0.5702
# car: 0.5450
# car: 0.5336
# car: 0.5327
# car: 0.5053
# Detection 수행시간: 0.08 초
# person: 0.7369
# person: 0.5472
# person: 0.5347
# bus: 0.5210
# Detection 수행시간: 0.07 초
# person: 0.7395
# person: 0.5635
# person: 0.5528
# bus: 0.5055
# Detection 수행시간: 0.08 초
# person: 0.7634
# person: 0.5408
# motorcycle: 0.5042
# Detection 수행시간: 0.08 초
# person: 0.7165
# person: 0.6531
# car: 0.6222
# Detection 수행시간: 0.08 초
# person: 0.7028
# person: 0.6651
# horse: 0.5503
# car: 0.5233
# Detection 수행시간: 0.08 초
# person: 0.7359
# person: 0.7221
# car: 0.5763
# bus: 0.5636
# Detection 수행시간: 0.08 초
# person: 0.7384
# person: 0.7165
# bus: 0.5937
# car: 0.5861
# Detection 수행시간: 0.07 초
# person: 0.6652
# person: 0.6397
# car: 0.6234
# person: 0.6091
# car: 0.5298
# horse: 0.5258
# person: 0.5253
# Detection 수행시간: 0.08 초
# person: 0.6791
# person: 0.6698
# car: 0.5651
# bus: 0.5499
# person: 0.5293
# person: 0.5126
# Detection 수행시간: 0.07 초
# person: 0.7131
# car: 0.6609
# person: 0.6088
# bus: 0.5382
# person: 0.5169
# Detection 수행시간: 0.08 초
# person: 0.7349
# car: 0.7101
# bus: 0.6678
# person: 0.6358
# car: 0.5849
# person: 0.5463
# person: 0.5072
# person: 0.5051
# Detection 수행시간: 0.09 초
# person: 0.7316
# car: 0.7031
# bus: 0.6545
# person: 0.6284
# car: 0.5680
# person: 0.5523
# person: 0.5115
# Detection 수행시간: 0.09 초
# person: 0.7273
# car: 0.7250
# bus: 0.6826
# car: 0.6480
# person: 0.6321
# person: 0.5264
# person: 0.5129
# person: 0.5128
# backpack: 0.5026
# Detection 수행시간: 0.08 초
# car: 0.7179
# person: 0.7047
# car: 0.6333
# bus: 0.5821
# person: 0.5567
# car: 0.5510
# person: 0.5467
# person: 0.5461
# car: 0.5098
# Detection 수행시간: 0.07 초
# person: 0.7323
# car: 0.6944
# person: 0.6005
# car: 0.5932
# car: 0.5834
# person: 0.5697
# person: 0.5651
# person: 0.5496
# bus: 0.5470
# bus: 0.5316
# car: 0.5139
# Detection 수행시간: 0.08 초
# person: 0.7935
# car: 0.6768
# car: 0.6356
# person: 0.6288
# person: 0.6168
# person: 0.5251
# person: 0.5180
# person: 0.5125
# car: 0.5096
# bus: 0.5012
# Detection 수행시간: 0.08 초
# person: 0.7906
# car: 0.6732
# person: 0.6401
# car: 0.6339
# person: 0.6289
# person: 0.5294
# car: 0.5277
# person: 0.5196
# person: 0.5129
# car: 0.5054
# Detection 수행시간: 0.08 초
# person: 0.8129
# car: 0.7049
# person: 0.6453
# car: 0.6374
# person: 0.5763
# car: 0.5356
# person: 0.5334
# car: 0.5267
# person: 0.5180
# person: 0.5124
# person: 0.5111
# person: 0.5013
# Detection 수행시간: 0.09 초
# person: 0.7622
# car: 0.7484
# person: 0.6381
# car: 0.5969
# person: 0.5793
# person: 0.5698
# car: 0.5386
# car: 0.5350
# person: 0.5146
# person: 0.5033
# Detection 수행시간: 0.08 초
# car: 0.7517
# person: 0.7381
# person: 0.6453
# person: 0.5985
# car: 0.5977
# car: 0.5569
# person: 0.5344
# person: 0.5310
# backpack: 0.5269
# person: 0.5186
# bus: 0.5167
# person: 0.5103
# Detection 수행시간: 0.08 초
# car: 0.7443
# person: 0.6962
# car: 0.5930
# person: 0.5864
# person: 0.5853
# car: 0.5802
# person: 0.5535
# bus: 0.5456
# bus: 0.5216
# Detection 수행시간: 0.09 초
# car: 0.7428
# person: 0.6968
# car: 0.5924
# person: 0.5813
# person: 0.5778
# car: 0.5666
# person: 0.5619
# bus: 0.5406
# bus: 0.5387
# Detection 수행시간: 0.08 초
# car: 0.7206
# person: 0.6786
# person: 0.6107
# car: 0.5838
# person: 0.5795
# person: 0.5733
# person: 0.5729
# bus: 0.5536
# motorcycle: 0.5483
# backpack: 0.5346
# person: 0.5164
# car: 0.5160
# bus: 0.5157
# Detection 수행시간: 0.08 초
# car: 0.6973
# person: 0.6946
# car: 0.6563
# person: 0.5825
# person: 0.5373
# motorcycle: 0.5327
# car: 0.5272
# person: 0.5212
# person: 0.5116
# Detection 수행시간: 0.09 초
# person: 0.7509
# car: 0.7313
# car: 0.6952
# person: 0.6422
# person: 0.6043
# person: 0.5767
# person: 0.5672
# person: 0.5660
# car: 0.5135
# motorcycle: 0.5131
# Detection 수행시간: 0.08 초
# person: 0.7357
# car: 0.7286
# car: 0.7214
# person: 0.6039
# person: 0.5903
# person: 0.5367
# person: 0.5321
# person: 0.5250
# person: 0.5091
# traffic light: 0.5051
# Detection 수행시간: 0.07 초
# person: 0.7310
# car: 0.7237
# car: 0.7169
# person: 0.6071
# person: 0.5812
# person: 0.5351
# person: 0.5308
# person: 0.5249
# traffic light: 0.5092
# Detection 수행시간: 0.08 초
# car: 0.7594
# person: 0.7123
# car: 0.6409
# person: 0.5721
# person: 0.5611
# car: 0.5093
# person: 0.5042
# traffic light: 0.5022
# Detection 수행시간: 0.08 초
# person: 0.7644
# car: 0.7509
# person: 0.6828
# person: 0.5515
# person: 0.5397
# car: 0.5281
# car: 0.5209
# car: 0.5206
# person: 0.5075
# person: 0.5031
# person: 0.5004
# Detection 수행시간: 0.08 초
# car: 0.7565
# person: 0.7481
# person: 0.6976
# person: 0.6066
# car: 0.5864
# person: 0.5407
# bicycle: 0.5249
# person: 0.5246
# person: 0.5230
# person: 0.5032
# Detection 수행시간: 0.08 초
# person: 0.7723
# car: 0.7415
# car: 0.6630
# person: 0.6345
# person: 0.5755
# person: 0.5379
# person: 0.5283
# car: 0.5281
# person: 0.5165
# car: 0.5078
# person: 0.5013
# Detection 수행시간: 0.08 초
# person: 0.7713
# car: 0.7474
# car: 0.6665
# person: 0.6326
# person: 0.5710
# person: 0.5382
# person: 0.5300
# car: 0.5279
# person: 0.5178
# person: 0.5146
# car: 0.5085
# Detection 수행시간: 0.08 초
# person: 0.7318
# car: 0.7291
# car: 0.7254
# person: 0.7085
# car: 0.6152
# person: 0.5985
# car: 0.5417
# person: 0.5402
# Detection 수행시간: 0.16 초
# person: 0.7599
# car: 0.7229
# car: 0.7176
# person: 0.6913
# person: 0.6340
# car: 0.5954
# car: 0.5493
# car: 0.5431
# bicycle: 0.5312
# person: 0.5130
# Detection 수행시간: 0.14 초
# person: 0.7522
# car: 0.7364
# car: 0.7213
# car: 0.6430
# person: 0.6416
# person: 0.6216
# car: 0.5797
# bicycle: 0.5395
# person: 0.5202
# car: 0.5138
# bicycle: 0.5034
# Detection 수행시간: 0.17 초
# 더 이상 처리할 frame이 없습니다.
